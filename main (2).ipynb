# %% [markdown]
# # Topic modelling (LDA)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
import nltk
from nltk import word_tokenize
import numpy as np
import gensim
from gensim.models.wrappers import LdaMallet
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pyLDAvis
stops = stopwords.words("english")

# %%
columns_to_drop = ['dataFrom', 'date', 'rating', 'extracted_devresp', 'devresp_time']
review_data = pd.read_csv('/Users/antheaang/Downloads/combined_data.csv').drop(columns_to_drop,axis=1)
review_data.head()
# Out:
#                                               review
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...

# %%
review_data.shape

# We have 14K reviews
# Out:
# (418, 1)

# %% [markdown]
# # Data Pre-Processing
# ### 1. Replacing/Dropping NULL values

# %%
review_data.isnull().sum()

# Since our data has no null values will be skip this step
# Out:
# review    0
# dtype: int64

# %% [markdown]
# ### 2. Converting to LOWER case

# %%
review_data['clean_review'] = review_data['review'].apply(lambda x: str(x).lower())
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  great banking app with attractive interest rat...
# 1  a bank like no other, no bank have such amazin...
# 2  notice that the drop in interest rate of 0.8% ...
# 3  sending money into my gxs account is a breeze ...
# 4  i have to say that the ui/ux is one of the bes...

# %% [markdown]
# ### 3. REMOVE NON-ALPHA DATA(DIGITS,PUNCTUATIONS,DIACRITICS)

# %%
review_data['clean_review'] = review_data['clean_review'].str.replace(r'[^a-zA-Z\s]', ' ',regex=True) 
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  great banking app with attractive interest rat...
# 1  a bank like no other  no bank have such amazin...
# 2  notice that the drop in interest rate of      ...
# 3  sending money into my gxs account is a breeze ...
# 4  i have to say that the ui ux is one of the bes...

# %% [markdown]
# ### 4. REMOVING WHITE SPACE

# %%
review_data['clean_review'] = review_data['clean_review'].str.replace(r'\s{2,}', ' ',regex=True)
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  great banking app with attractive interest rat...
# 1  a bank like no other no bank have such amazing...
# 2  notice that the drop in interest rate of in sa...
# 3  sending money into my gxs account is a breeze ...
# 4  i have to say that the ui ux is one of the bes...

# %% [markdown]
# ### 5. WORD TOKENIZATION

# %%
review_data['clean_review'] = review_data['clean_review'].apply(lambda x: word_tokenize(x))
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  [great, banking, app, with, attractive, intere...
# 1  [a, bank, like, no, other, no, bank, have, suc...
# 2  [notice, that, the, drop, in, interest, rate, ...
# 3  [sending, money, into, my, gxs, account, is, a...
# 4  [i, have, to, say, that, the, ui, ux, is, one,...

# %% [markdown]
# ### 6. REMOVE UNNECESSARY WORDS

# %%
review_data['clean_review'] = review_data['clean_review'].apply\
(lambda x:[word for word in x if word not in stopwords.words("english") and len(word) > 3 and word.isalpha()])

review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  [great, banking, attractive, interest, rates, ...
# 1  [bank, like, bank, amazing, feature, separate,...
# 2  [notice, drop, interest, rate, saving, account...
# 3  [sending, money, account, breeze, instantaneou...
# 4  [best, seen, digibank, mobile, finally, strong...

# %%
# for dev_response
'''custom_stopwords = ['Hi', 'please', 'thank you', 'happy', 'thrilled', 'delighted', 'thank', 'there', 'review', 'sorry', 'hope',]
review_data['clean_review'] = review_data['clean_review'].apply\
(lambda x:[word for word in x if word not in custom_stopwords and len(word) > 3 and word.isalpha()]) '''
# Out:
# "custom_stopwords = ['Hi', 'please', 'thank you', 'happy', 'thrilled', 'delighted', 'thank', 'there', 'review', 'sorry', 'hope',]\nreview_data['clean_review'] = review_data['clean_review'].apply(lambda x:[word for word in x if word not in custom_stopwords and len(word) > 3 and word.isalpha()]) "

# %%
review_data = review_data[review_data['clean_review'].map(lambda x: len(x)) > 1].reset_index(drop=True)
# Keeping records with more than single words

# %% [markdown]
# ### 7. LEMMATIZATION

# %%
review_data['clean_review'] = review_data['clean_review'].apply\
(lambda x: [WordNetLemmatizer().lemmatize(word) for word in x])
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  [great, banking, attractive, interest, rate, p...
# 1  [bank, like, bank, amazing, feature, separate,...
# 2  [notice, drop, interest, rate, saving, account...
# 3  [sending, money, account, breeze, instantaneou...
# 4  [best, seen, digibank, mobile, finally, strong...

# %% [markdown]
# ### 8. Extracting only NOUN

# %%
review_data['clean_review'] = review_data['clean_review'].apply\
(lambda x: [word for word in x if nltk.pos_tag([word])[0][1] == 'NN'])

# %%
review_data = review_data[review_data['clean_review'].map(lambda x: len(x)) > 1].reset_index(drop=True)
# Keeping records with more than single words

# %%
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review
# 0  [banking, interest, rate, please, payee, numbe...
# 1  [bank, bank, feature, money, pocket, track, go...
# 2  [notice, drop, interest, rate, account, reason...
# 3  [money, account, breeze, amount, fund, money, ...
# 4  [digibank, mobile, market, player, focus, cust...

# %% [markdown]
# ### 9. Document Term Matrix

# %%
dictionary = corpora.Dictionary(review_data['clean_review'])
print(dictionary)

# We have 6724 unique tokens
# Out:
# Dictionary(738 unique tokens: ['account', 'apple', 'banking', 'card', 'debit']...)

# %%
doc_term_matrix = review_data['clean_review'].apply(lambda x: dictionary.doc2bow(x))
doc_term_matrix[:10]

# Each tokenized words has been assigned index value and thier count in corpus
# Out:
# 0    [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1...
# 1    [(5, 3), (9, 1), (10, 3), (11, 1), (12, 1), (1...
# 2    [(0, 9), (5, 7), (9, 6), (10, 1), (34, 1), (35...
# 3    [(0, 2), (2, 1), (8, 1), (23, 2), (30, 1), (43...
# 4    [(2, 1), (8, 1), (10, 1), (26, 1), (33, 1), (6...
# 5    [(0, 1), (10, 4), (42, 1), (61, 1), (83, 1), (...
# 6    [(2, 1), (5, 1), (9, 1), (10, 1), (32, 1), (74...
# 7    [(2, 1), (7, 1), (10, 3), (17, 1), (23, 1), (3...
# 8    [(17, 1), (25, 1), (32, 1), (33, 1), (74, 1), ...
# 9    [(0, 2), (6, 1), (8, 1), (10, 3), (21, 1), (56...
# Name: clean_review, dtype: object

# %% [markdown]
# ### SEEDING LDA

# %%
App_Responsiveness = ['freeze', 'crash', 'buggy', 'speed', 'fast', 'crash', 'swift', 'rapid', 'seamless', 'smooth', 'wait', 'snappy', 'load', 'efficient', 'error']
Money_Growth = ['drop', 'interest rate', 'ROI', 'interest', 'rates', 'savings', 'p.a.']
Customer_Services = ['wait time', 'efficient', 'response', 'customer', 'support', 'hotline', 'email', 'feedback','suggestion']
Services_and_Products = ['deposit', 'repayment', 'loan', 'pocket', 'digital', 'transfer', 'payee', 'saving', 'convenient', 'QR', 'deposit']
User_Interface = ['ease', 'use', 'easy', 'clear', 'friendly', 'seamless', 'functionality', 'graphics', 'design', 'UI', 'UX', 'theme', 'UI/UX', 'interface', 'intuitive']
Credit_card = ['rebates', 'debit', 'creditcard', 'credit', 'card']
Login_Account_Setup = ['registration', 'singpass', 'password', 'biometric', 'onboard', 'setup', 'set', 'up', 'login' , 'open', 'signup', 'fingerprint', 'launch', 'register', 'create', 'application', '2FA', 'download', 'biometrics', 'sign']
Competition = ['Trust', 'maribank', 'T' , 'bills', 'OCBC', 'Timo']
Safety = ['password', 'pin', 'particulars', 'hack', 'security', 'secure', 'safe']
Customer_trust = ['misleading', 'deceive', 'fake' , 'false', 'scam']

# %%
seed_topics = {}
for word in App_Responsiveness:
    seed_topics[word] = 0
for word in Money_Growth:
    seed_topics[word] = 1
for word in Customer_Services:
    seed_topics[word] = 2
for word in Services_and_Products:
    seed_topics[word] = 3
for word in User_Interface:
    seed_topics[word] = 4
for word in Credit_card:
    seed_topics[word] = 5
for word in Login_Account_Setup:
    seed_topics[word] = 6
for word in Competition:
    seed_topics[word] = 7
for word in Safety:
    seed_topics[word] = 8
for word in Customer_trust:
    seed_topics[word] = 9

# %%
def create_eta(priors, etadict, ntopics):
    eta = np.full(shape=(ntopics, len(etadict)), fill_value=1) # create a (ntopics, nterms) matrix and fill with 1
    for word, topic in priors.items(): # for each word in the list of priors
        keyindex = [index for index,term in etadict.items() if term==word] # look up the word in the dictionary
        if (len(keyindex)>0): # if it's in the dictionary
            eta[topic,keyindex[0]] = 1e7  # put a large number in there
    eta = np.divide(eta, eta.sum(axis=0)) # normalize so that the probabilities sum to 1 over all topics
    return eta

# %%
eta = create_eta(seed_topics, dictionary, 10)

# %% [markdown]
# ### LDA

# %%
os.environ['MALLET_HOME'] = "/Users/antheaang/Downloads/mallet-2.0.8"
print(os.getenv("MALLET_HOME"))
mallet_path = "/Users/antheaang/Downloads/mallet-2.0.8/bin/mallet"

ldamallet = LdaMallet(mallet_path, corpus=doc_term_matrix, num_topics=10, id2word=dictionary)
# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=review_data['clean_review'], dictionary=dictionary, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# /Users/antheaang/Downloads/mallet-2.0.8
# Mallet LDA: 10 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 49
# total tokens: 2292
# <10> LL/token: -7.91195
# <20> LL/token: -7.65623
# <30> LL/token: -7.53719
# <40> LL/token: -7.41482
#
# 0	5	interest rate simple trust waste point till product news drop consumer explain cool chat attempt effort beautiful scammer industry spent
# 1	5	sign user experience feature deposit design money message opening developer lousy suggestion start provide market ecosystem signing meet proper build
# 2	5	account bank payee interest increase register reason year dont grow term spend response asap maximum invitation space public pas gxbank
# 3	5	issue fast singpass review update hope page password min joke setup criterion buggy display yesterday loan response cash doubt kudos
# 4	5	phone money wait transfer screen service customer ease star kind join advice le information clean company buddy sept emergency type
# 5	5	login banking apps digital super rating problem process store day change support attempt security slot idea play respond move sleek
# 6	5	error application download launch love detail stuck everytime transfer payment useless show smooth code quick past space promise transparent change
# 7	5	pocket bank number function fund repayment goal singtel navigate touch time create straight week info lack seamless everyday secure device
# 8	5	time loan month email told singpass fund multiple transaction amount today number borrow approval receive click question notification limit hassle
# 9	5	account work grab interface offer access card list thing force flexiloan debit registration link singapore proceed understand competitor mobile notice
#
# <50> LL/token: -7.40602
# <60> LL/token: -7.43087
# <70> LL/token: -7.39865
# <80> LL/token: -7.4262
# <90> LL/token: -7.42494
#
# 0	5	interest rate simple trust increase point feature quick product cool public competitor drop invitation pas hope clean market decrease found
# 1	5	sign user feature experience design deposit security borrow join interface idea developer provide ecosystem project chat fingerprint notification application load
# 2	5	account bank payee reason page banking kind criterion space consumer company option encourage maximum imagine recipient spend proper notice card
# 3	5	loan singpass fast issue update fund digital review hope joke limit start min bank suggestion promise overlay signing write life
# 4	5	money phone wait account screen service list everytime transfer password proceed star write hassle device foreigner excellent mobile fund collect
# 5	5	login banking download application rating register problem support stuck process store day term ease question play le attempt stay staff
# 6	5	transfer error apps love detail experience change payment show goal click dont create useless smooth code slot paynow transparent meet
# 7	5	bank pocket number function singtel navigate setup message flexiloan approval lack touch review past lousy secure yesterday information bait respond
# 8	5	time month email told launch waste multiple transaction amount response repayment week receive grow feel display info today customer buddy
# 9	5	work grab account offer interface access thing super year card force till debit buggy opening link credit cash improvement everyday
#
# <100> LL/token: -7.4602
# <110> LL/token: -7.37699
# <120> LL/token: -7.35312
# <130> LL/token: -7.36066
# <140> LL/token: -7.34946
#
# 0	5	interest rate simple increase rating security criterion drop earn information stay point notice case cap registration merchant access dark excellent
# 1	5	sign user feature interface experience stuck week kind setup straight news quick code company sleek theme doubt kudos overlay sgqr
# 2	5	account payee banking card bank useless opening grow consumer force lousy yesterday notification input ocbc chat imagine question alternative registration
# 3	5	loan fast issue update digital apps review design repayment min le show developer offer product display public load improvement asap
# 4	5	money phone transfer wait screen service function list dont today borrow everytime bother device move goal banking signing create thing
# 5	5	login error application experience download pocket register offer support hope process customer flexiloan attempt response reason credit transparent proper understand
# 6	5	love trust detail change problem payment apps click space password smooth term star cash point create hassle spend provide mobile
# 7	5	bank pocket singpass number fund approval singtel past paynow mistake portion breeze everyday scheme press cover galaxy advertise race reapply
# 8	5	time month launch told email waste multiple transaction amount day proceed ease touch review joke limit receive link download seamless
# 9	5	work grab fund deposit super page access store year till navigate thing message buggy write info singapore debit explain play
#
# <150> LL/token: -7.36982
# <160> LL/token: -7.37199
# <170> LL/token: -7.38731
# <180> LL/token: -7.38328
# <190> LL/token: -7.35627
#
# 0	5	interest rate interface simple increase point payment thing navigate drop information bait cash improvement case sept digit feedback useless hassle
# 1	5	sign user feature interest love join ease start quick slot secure write understand theme ecosystem overlay registration transparent everyday modify
# 2	5	account banking payee service card reason click joke debit borrow opening suggestion bother proper load credit staff ocbc company emergency
# 3	5	loan fast issue review update launch offer repayment min approval singapore display question notification stay developer doubt past imagine gxbank
# 4	5	money phone transfer wait screen problem list process function day today public yesterday login market digi alternative buggy perfect select
# 5	5	pocket login experience error download digital application hope page attempt customer password security everytime code limit simple useless respond store
# 6	5	apps detail change support stuck show flexiloan space create week kind message straight news lack smooth promise spend info switch
# 7	5	bank singpass number design force star le seamless consumer pocket lousy access sleek product cap signing cool foreigner version write
# 8	5	time month email told multiple transaction amount waste response dont proceed touch register receive link love effort asap maximum explain
# 9	5	work grab fund trust super rating year goal till access deposit criterion singtel feel advice setup idea clean competitor store
#
# <200> LL/token: -7.34306
# <210> LL/token: -7.39607
# <220> LL/token: -7.36441
# <230> LL/token: -7.42335
# <240> LL/token: -7.43599
#
# 0	5	interest rate simple interface deposit increase point function flexiloan thing drop consumer improvement notice invitation august collect throat pain wireframe
# 1	5	sign user feature love stuck payment everytime year setup borrow lack cash past secure link move mistake buddy project recipient
# 2	5	account banking payee access hope reason debit suggestion paynow earn company theme case limit bait build switch ocbc decrease rider
# 3	5	loan issue update review apps offer repayment fast amount create ease min join star today problem display lousy cool device
# 4	5	phone transfer wait screen application list week proceed le info security credit quick detail problem yesterday bother straight grow competitor
# 5	5	pocket login experience error download launch page space useless password attempt touch money application idea play respond signing carry gxbank
# 6	5	money digital service fast change month support show click till detail product message registration news term loan spend apps staff
# 7	5	bank singpass number design process force kind feel seamless fast developer effort approval slot foreigner public annum told meet type
# 8	5	time email interest waste multiple told rating register transaction month goal day response smooth criterion dont code buggy opening receive
# 9	5	work grab fund trust super card store write navigate joke singtel customer advice feature information clean stay sleek load input
#
# <250> LL/token: -7.39261
# <260> LL/token: -7.39131
# <270> LL/token: -7.35804
# <280> LL/token: -7.40052
# <290> LL/token: -7.35836
#
# 0	5	interest rate increase function thing reason point flexiloan drop consumer deposit clean company device notice dark awesome decrease pain serve
# 1	5	sign user feature interface love change payment year setup registration quick fund display suggestion loan meet credit popped secure pas
# 2	5	account banking pocket payee access hope week space earn info move buddy signing yesterday bait spend screen build emergency paid
# 3	5	loan issue update review simple transfer problem amount list process repayment register deposit start slot past proper sleek seamless doubt
# 4	5	phone wait transfer application screen stuck attempt show everytime dont proceed security smooth lack product notification bother blank chat question
# 5	5	login experience pocket error download launch page click ease joke message join min information transparent respond competitor mistake theme invitation
# 6	5	money apps service offer detail support till write today approval news grow super goal feature lousy explain public paynow le
# 7	5	bank fast number design force kind limit developer launch everyday play create term load mobile market asap ecosystem maximum install
# 8	5	time month email told grab waste multiple rating transaction response star customer day criterion opening link receive ocbc encourage cap
# 9	5	singpass work digital fund trust card grab store singtel debit buggy borrow straight super cash navigate singapore improvement advice code
#
# <300> LL/token: -7.36052
# <310> LL/token: -7.38936
# <320> LL/token: -7.34927
# <330> LL/token: -7.37864
# <340> LL/token: -7.37707
#
# 0	5	interest rate increase deposit function thing point reason payee navigate drop consumer meet notice case stuck dark bait ocbc decrease
# 1	5	sign user application interface offer change repayment news quick effort message suggestion company input rating ecosystem maximum project sgqr pas
# 2	5	account banking simple access hope dont week joke registration info fast slot click payment opening spend competitor everyday encourage fingerprint
# 3	5	loan issue update screen review amount list process till create register smooth le join proper understand option wait overlay question
# 4	5	phone transfer wait super security everytime show proceed kind today stuck code straight product display paynow buggy write bother stay
# 5	5	pocket login experience error download love attempt page min force setup developer past idea information promise limit respond device seamless
# 6	5	money feature apps detail design problem service bank support ease time goal explain transparent load switch staff customer chat foreigner
# 7	5	bank number fast launch payee space useless approval term start singapore password feel mobile lousy excuse share holder scheme objective
# 8	5	time grab month email told multiple waste transaction response day rating criterion receive link lack touch payment customer doubt pull
# 9	5	singpass work fund digital trust card store year flexiloan singtel debit borrow star service cool play clean hassle sleek cap
#
# <350> LL/token: -7.33066
# <360> LL/token: -7.37457
# <370> LL/token: -7.41122
# <380> LL/token: -7.40524
# <390> LL/token: -7.3691
#
# 0	5	interest rate increase deposit function thing point love interface receive lack drop notification switch phone provide notice case bait market
# 1	5	sign user application offer change interface kind smooth setup buggy start quick effort support information clean meet news store theme
# 2	5	account banking access simple response star min dont le singapore improvement play hope earn singtel proper spend info understand build
# 3	5	loan update review screen service issue amount list process show useless write password simple message criterion attempt register support till
# 4	5	transfer phone wait super payment repayment security goal click stuck proceed product code ease today everyday paynow straight respond asap
# 5	5	pocket login error experience page love issue space week touch limit cash display lousy promise option download force screenshot standard
# 6	5	money feature apps detail rating design problem customer hope navigate debit credit issue yesterday opening encourage doubt maximum invitation blank
# 7	5	bank fast payee number launch grab create joke term past bother approval competitor staff ocbc question pas registration singtel load
# 8	5	time month email told download grab waste multiple transaction reason everytime day link store stay move slot ecosystem explain sept
# 9	5	singpass work fund digital trust card year flexiloan experience borrow developer advice force cool idea grow device chat secure till
#
# <400> LL/token: -7.36361
# <410> LL/token: -7.41363
# <420> LL/token: -7.37568
# <430> LL/token: -7.34308
# <440> LL/token: -7.28712
#
# 0	5	interest rate increase thing point function smooth info lack developer singapore drop consumer navigate notice deposit pas borrow dark promise
# 1	5	sign user application interface offer change register store deposit news term suggestion play information option till understand autocracy organisation section
# 2	5	account banking access stuck response singtel star min customer product debit criterion proceed receive start buggy advice case card online
# 3	5	loan issue screen simple download review list write message year display public dont notification attempt limit bait respond switch theme
# 4	5	phone wait transfer super payment repayment security goal click create today setup join improvement everyday lousy secure attempt sleek quick
# 5	5	pocket login experience error love service page space week touch review transparent competitor stay cap doubt maximum gxbank chance useless
# 6	5	money feature apps detail hope problem grab pocket le credit slot effort past explain yesterday useless clean input ecosystem encourage
# 7	5	bank fast payee number launch transfer rating design amount force password joke flexiloan process question approval card signing cool idea
# 8	5	time month email told grab waste multiple transaction show everytime reason day code link hassle meet move feel mistake staff
# 9	5	singpass work fund update digital trust support kind registration straight grow cash till paynow spend sgqr sept imagine recipient opening
#
# <450> LL/token: -7.3525
# <460> LL/token: -7.3703
# <470> LL/token: -7.37495
# <480> LL/token: -7.4303
# <490> LL/token: -7.38637
#
# 0	5	interest rate account increase point write limit drop consumer criterion spend notice case reinstall dark build decrease effort absurd section
# 1	5	sign user interface offer deposit change application list process register store buggy news ease clean understand star everyday encourage maximum
# 2	5	account banking launch card stuck show touch product debit opening receive feel singapore advice past question input ocbc click code
# 3	5	loan issue update screen simple review response dont year joke smooth flexiloan week developer display borrow competitor repayment sleek staff
# 4	5	phone wait waste amount payment attempt goal create security multiple straight today explain play bother bait info grow repayment mistake
# 5	5	pocket login experience error love service super message registration hope seamless everytime navigate suggestion earn stay move buddy blank version
# 6	5	money feature apps grab problem function detail page useless le hope proceed join lack slot setup yesterday transparent provide foreigner
# 7	5	bank transfer fast payee number download rating customer public information link signing recipient excellent credit share note insult flag organisation
# 8	5	time month email told transaction reason day password click lousy space till multiple hassle meet device load sept imagine check
# 9	5	singpass work digital trust fund bank access design thing application force support min singtel term start kind improvement cool market
#
# <500> LL/token: -7.38694
# <510> LL/token: -7.40671
# <520> LL/token: -7.45307
# <530> LL/token: -7.3645
# <540> LL/token: -7.47337
#
# 0	5	interest rate account increase thing point flexiloan drop limit competitor switch asap notice consumer earn build move offering excuse decrease
# 1	5	sign user application interface offer change stuck process store security singpass deposit buggy credit past information quick rating pull waste
# 2	5	account issue launch card show goal force touch product debit smooth year cash slot singapore suggestion clean input provide mobile
# 3	5	loan fast screen review user update simple dont star kind joke setup registration opening week link join advice secure yesterday
# 4	5	phone wait banking multiple amount waste support payment attempt create pocket message grow public paynow spend understand mistake staff market
# 5	5	pocket login experience error fund love banking super register password ease seamless navigate everyday display explain company hassle option everytime
# 6	5	feature grab apps month service detail problem function page update response useless proceed code hope approval lack feel developer design
# 7	5	bank transfer payee number time list write receive news cool foreigner gxbank breeze flag delivery school concern painful awful homepage
# 8	5	time money email told transaction reason click day today criterion hope straight repayment lousy question notification overlay hour chat sept
# 9	5	singpass work bank download digital trust access simple customer space till rating singtel info design idea start min cap invitation
#
# <550> LL/token: -7.42233
# <560> LL/token: -7.38301
# <570> LL/token: -7.41423
# <580> LL/token: -7.40098
# <590> LL/token: -7.40223
#
# 0	5	interest rate change increase thing point account card message seamless drop bait market case doubt signing gxbank le staff decrease
# 1	5	sign user application offer deposit waste process year interface cash bank suggestion information clean security maintain feature redundant absurd scene
# 2	5	account launch force week min touch debit smooth attempt limit digital slot play buggy bother company ocbc notice icon annum
# 3	5	loan fast issue fund update review screen payment store dont star opening consumer effort display past registration quick encourage overlay
# 4	5	phone detail rating problem support everytime flexiloan ease create code info grow singapore banking question paynow hassle spend security provide
# 5	5	pocket experience wait error love banking super register design page write simple navigate advice explain competitor digi blank carry online
# 6	5	apps grab feature month service hope response function goal useless proceed kind approval yesterday promise cap maximum invitation concept august
# 7	5	bank transfer payee number money multiple show list interface banking phone link credit joke developer sleek switch mistake chat pas
# 8	5	time singpass money email told transaction reason repayment click password today setup criterion stuck borrow straight receive amount notification earn
# 9	5	login work bank download trust digital access simple customer day space till product singtel start feel theme asap ecosystem project
#
# <600> LL/token: -7.3997
# <610> LL/token: -7.37865
# <620> LL/token: -7.39947
# <630> LL/token: -7.3734
# <640> LL/token: -7.3707
#
# 0	5	interest rate account increase card thing point approval drop clean info option input notice registration month throat shout flawless beautiful
# 1	5	user phone interface offer deposit update change bank function process security year stuck week touch response kind improvement transfer product
# 2	5	account singpass application digital attempt update service force min message super cash yesterday hassle understand slot debit maximum code emergency
# 3	5	loan fast issue fund screen review store dont star smooth criterion lousy opening bother promise bait device cool chat sept
# 4	5	sign phone waste rating account support flexiloan write download show news grow problem advice setup secure question payment spend stay
# 5	5	pocket wait experience love banking design register page navigate lack credit everyday display paynow straight company super seamless encourage kudos
# 6	5	feature apps grab month hope goal useless proceed service create limit effort payment respond proper link move market amount pull
# 7	5	bank transfer payee number error detail multiple list everytime singapore le switch staff developer gxbank earn ease type mistake life
# 8	5	time money email told banking access transaction reason repayment today amount borrow singpass problem consumer buggy password notification carry foreigner
# 9	5	bank login work trust simple download launch customer click day space till singtel term feel start quick past idea ease
#
# <650> LL/token: -7.44703
# <660> LL/token: -7.41154
# <670> LL/token: -7.34561
# <680> LL/token: -7.32746
# <690> LL/token: -7.39589
#
# 0	5	interest rate account increase thing card approval news quick point notification information bait notice cap signing smooth living pas annum
# 1	5	user interface offer update phone function process year week security touch message straight info effort transparent term product lousy gxbank
# 2	5	account singpass application digital work wait register debit opening start credit slot singtel check yesterday till recipient merchant didnt perfect
# 3	5	loan fast issue phone review screen waste password setup criterion singapore display cool dont hassle respond singpass overlay smooth digi
# 4	5	sign download rating problem support payment show store flexiloan write joke grow advice everyday question code meet spend competitor stay
# 5	5	pocket banking experience error love detail design wait page super create min le lack navigate consumer paynow staff theme point
# 6	5	apps fund grab month service hope response repayment everytime stuck multiple useless attempt proceed space registration link cash wait explain
# 7	5	bank transfer feature payee number list update kind developer improvement click option mobile force suggestion earn switch type mistake reviewer
# 8	5	time money email told access amount transaction deposit star today reason day buggy borrow download drop force move ecosystem marketing
# 9	5	bank login simple trust launch work change customer goal ease past secure till promise clean proper understand join doubt invitation
#
# <700> LL/token: -7.42866
# <710> LL/token: -7.37076
# <720> LL/token: -7.34822
# <730> LL/token: -7.39885
# <740> LL/token: -7.407
#
# 0	5	interest rate increase point ease fund smooth drop start ocbc notice pull public annum feel excuse decrease insult concern slip
# 1	5	user update interface offer function password week repayment navigate product criterion write info effort explain idea suggestion bait option touch
# 2	5	account singpass application deposit register process customer singtel month le join seamless credit rating consumer notification encourage buddy invitation blank
# 3	5	loan phone fast issue review screen amount fund dont setup registration approval proceed display hassle theme popped imagine merchant color
# 4	5	sign download waste design problem support payment show force min space grow store advice question paynow respond staff rating cap
# 5	5	pocket wait error experience login detail love super page security useless straight device move ecosystem create meet news slot mobile
# 6	5	banking apps grab service multiple hope month reason stuck attempt response year click message link kind thing earn market fund
# 7	5	bank transfer feature payee number digital list everytime code cash singapore improvement debit information term input thing project gxbank recipient
# 8	5	time money email told access transaction till today day buggy borrow receive lack developer cool sleek singpass chat sept carry
# 9	5	bank work simple trust launch login change experience card flexiloan joke opening quick everyday lousy create proper star mistake provide
#
# <750> LL/token: -7.36839
# <760> LL/token: -7.35231
# <770> LL/token: -7.37176
# <780> LL/token: -7.36898
# <790> LL/token: -7.44803
#
# 0	5	interest rate increase point flexiloan join start drop consumer bait provide notice fund case cap foreigner year excuse collect scheme
# 1	5	user update interface offer transfer design function customer product borrow straight limit lack cash improvement account lousy cool clean encourage
# 2	5	account singpass application deposit reason attempt store singtel min force le credit past message registration move doubt pull july secure
# 3	5	loan phone fast issue review screen fund amount register approval feel suggestion question theme transfer overlay sept convenient life breeze
# 4	5	sign login download rating problem list show space smooth dont link advice display meet month today everyday project support loan
# 5	5	pocket wait love experience detail super waste security create week navigate yesterday information company device seamless asap ecosystem blank click
# 6	5	banking apps error grab service month multiple stuck page useless write ease kind debit account hope slot click explain earn
# 7	5	bank feature payee number digital transfer experience payment goal buggy everytime thing code notification proceed hassle effort kudos paynow term
# 8	5	time money email told access transaction day password setup support receive grow touch criterion response stay option sleek load staff
# 9	5	bank work simple trust launch change card till joke hope opening process info repayment quick proper mistake fingerprint promise proceed
#
# <800> LL/token: -7.36506
# <810> LL/token: -7.35204
# <820> LL/token: -7.37725
# <830> LL/token: -7.3615
# <840> LL/token: -7.29234
#
# 0	5	interest rate increase point support drop consumer yesterday earn promise bait mobile ocbc notice case switch select market decrease button
# 1	5	user update interface offer design payment security year customer force flexiloan code straight news start improvement product suggestion information clean
# 2	5	account singpass application deposit list reason attempt click process registration join credit min developer setup criterion provide company competitor continue
# 3	5	loan phone issue fast fund review screen singtel kind joke approval advice stay cash amount overlay pull fingerprint type insult
# 4	5	sign login download simple card rating thing store space password today term digital slot cool secure question blank buggy dark
# 5	5	pocket wait experience love detail super waste create navigate debit le lack digital touch idea bother respond staff minimum meet
# 6	5	banking apps grab error service month multiple page function useless write star amount past explain move hour pas gxbank paynow
# 7	5	bank transfer feature payee number everytime stuck proceed repayment ease digital borrow opening month lousy limit option mistake encourage maximum
# 8	5	time money email told access transaction response goal day week smooth receive info quick effort message notification hassle fast ecosystem
# 9	5	bank work trust launch hope change problem register till show simple dont link singapore spend proper device doubt kudos project
#
# <850> LL/token: -7.31089
# <860> LL/token: -7.32783
# <870> LL/token: -7.3731
# <880> LL/token: -7.36668
# <890> LL/token: -7.35331
#
# 0	5	interest rate increase thing point drop consumer bother bait case feature bank ecosystem maximum invitation project switch asap breeze offering
# 1	5	user update offer interface super design show security force flexiloan password customer pocket news start year developer improvement advice suggestion
# 2	5	account login application singpass fund attempt reason borrow limit join credit service everyday effort registration meet reinstall imagine question fingerprint
# 3	5	loan phone fast issue banking review screen amount click singtel joke approval link payee display past idea information cap overlay
# 4	5	sign download waste rating store dont week term feel transaction proceed stay ocbc play form flexi cancel grow build kind
# 5	5	pocket wait experience love detail function digital create useless lack product setup cool page code proper seamless cash navigate mobile
# 6	5	apps error grab month card service deposit support payment process response digital write ease smooth message info debit explain respond
# 7	5	bank transfer feature number payee change stuck repayment everytime min opening competitor mistake lousy sgqr paynow merchant le proceed type
# 8	5	time money email singpass told access multiple list goal day space star phone touch today buggy receive doubt buddy chat
# 9	5	bank work simple trust launch hope problem register till quick singapore public page promise transparent company provide month market encourage
#
# <900> LL/token: -7.37577
# <910> LL/token: -7.34292
# <920> LL/token: -7.34833
# <930> LL/token: -7.34839
# <940> LL/token: -7.36489
#
# 0	5	interest rate increase thing navigate point registration feel drop consumer company star switch ocbc notice case ecosystem overlay project merchant
# 1	5	user offer detail design banking security super year click password show message singtel news link term slot secure information transparent
# 2	5	account login singpass fund application proceed response reason start credit question bother limit respond cap straight build move load improvement
# 3	5	loan phone fast issue update review screen account smooth setup day borrow approval lack yesterday asap support pas grow flag
# 4	5	sign transfer waste rating store change banking space download digital developer play week theme doubt kudos display invitation auto install
# 5	5	pocket wait experience love deposit digital function banking useless product goal create effort cool sleek market service advice chat version
# 6	5	grab error apps month amount card service page write kind debit payment buggy account past paynow access info cash buddy
# 7	5	bank feature payee transfer number interface download stuck repayment ease everytime force everyday account idea promise spend device mistake touch
# 8	5	time money email told multiple transaction list attempt access singpass customer receive join seamless quick today explain sept check code
# 9	5	bank work simple trust launch hope problem register joke criterion till le opening singapore dont process clean input provide encourage
#
# <950> LL/token: -7.41721
# <960> LL/token: -7.3892
# <970> LL/token: -7.38575
# <980> LL/token: -7.32023
# <990> LL/token: -7.37268
# [(0,
#   [('interest', 0.3146551724137931),
#    ('rate', 0.23706896551724138),
#    ('increase', 0.03879310344827586),
#    ('point', 0.03017241379310345),
#    ('consumer', 0.017241379310344827),
#    ('lack', 0.017241379310344827),
#    ('thing', 0.017241379310344827),
#    ('drop', 0.017241379310344827),
#    ('device', 0.01293103448275862),
#    ('bait', 0.01293103448275862)]),
#  (1,
#   [('user', 0.12322274881516587),
#    ('offer', 0.052132701421800945),
#    ('detail', 0.04265402843601896),
#    ('super', 0.037914691943127965),
#    ('design', 0.037914691943127965),
#    ('security', 0.02843601895734597),
#    ('support', 0.02843601895734597),
#    ('year', 0.02843601895734597),
#    ('payment', 0.02843601895734597),
#    ('click', 0.023696682464454975)]),
#  (2,
#   [('account', 0.23412698412698413),
#    ('login', 0.08333333333333333),
#    ('fund', 0.06349206349206349),
#    ('application', 0.051587301587301584),
#    ('told', 0.027777777777777776),
#    ('page', 0.023809523809523808),
#    ('star', 0.01984126984126984),
#    ('proceed', 0.01984126984126984),
#    ('repayment', 0.01984126984126984),
#    ('register', 0.015873015873015872)]),
#  (3,
#   [('loan', 0.10317460317460317),
#    ('phone', 0.0992063492063492),
#    ('fast', 0.07539682539682539),
#    ('issue', 0.07142857142857142),
#    ('update', 0.05555555555555555),
#    ('review', 0.05555555555555555),
#    ('screen', 0.03968253968253968),
#    ('amount', 0.031746031746031744),
#    ('show', 0.023809523809523808),
#    ('response', 0.023809523809523808)]),
#  (4,
#   [('sign', 0.20095693779904306),
#    ('download', 0.05741626794258373),
#    ('rating', 0.03827751196172249),
#    ('problem', 0.03827751196172249),
#    ('reason', 0.03349282296650718),
#    ('simple', 0.028708133971291867),
#    ('store', 0.028708133971291867),
#    ('attempt', 0.028708133971291867),
#    ('navigate', 0.023923444976076555),
#    ('hope', 0.023923444976076555)]),
#  (5,
#   [('pocket', 0.16143497757847533),
#    ('wait', 0.08520179372197309),
#    ('experience', 0.08071748878923767),
#    ('digital', 0.05829596412556054),
#    ('love', 0.04932735426008968),
#    ('deposit', 0.03587443946188341),
#    ('function', 0.03139013452914798),
#    ('create', 0.02242152466367713),
#    ('space', 0.02242152466367713),
#    ('write', 0.02242152466367713)]),
#  (6,
#   [('banking', 0.08333333333333333),
#    ('apps', 0.0784313725490196),
#    ('grab', 0.07352941176470588),
#    ('error', 0.07352941176470588),
#    ('month', 0.06372549019607843),
#    ('card', 0.0392156862745098),
#    ('singpass', 0.029411764705882353),
#    ('debit', 0.024509803921568627),
#    ('dont', 0.024509803921568627),
#    ('link', 0.0196078431372549)]),
#  (7,
#   [('transfer', 0.11059907834101383),
#    ('feature', 0.07834101382488479),
#    ('payee', 0.07834101382488479),
#    ('number', 0.06912442396313365),
#    ('interface', 0.041474654377880185),
#    ('everytime', 0.027649769585253458),
#    ('password', 0.02304147465437788),
#    ('force', 0.02304147465437788),
#    ('feel', 0.018433179723502304),
#    ('credit', 0.018433179723502304)]),
#  (8,
#   [('time', 0.14919354838709678),
#    ('money', 0.11693548387096774),
#    ('singpass', 0.07258064516129033),
#    ('email', 0.04838709677419355),
#    ('waste', 0.03225806451612903),
#    ('multiple', 0.03225806451612903),
#    ('change', 0.03225806451612903),
#    ('access', 0.03225806451612903),
#    ('transaction', 0.03225806451612903),
#    ('list', 0.028225806451612902)]),
#  (9,
#   [('bank', 0.3237704918032787),
#    ('account', 0.0778688524590164),
#    ('work', 0.07377049180327869),
#    ('trust', 0.05327868852459016),
#    ('launch', 0.04918032786885246),
#    ('simple', 0.028688524590163935),
#    ('process', 0.02459016393442623),
#    ('kind', 0.020491803278688523),
#    ('singapore', 0.01639344262295082),
#    ('input', 0.012295081967213115)])]
# 0	5	interest rate increase point lack thing drop consumer straight bait device switch notice case everyday kudos pull alternative select mistake
# 1	5	user offer detail super design payment security year click flexiloan support message news min developer display buggy hassle grow thing
# 2	5	account login fund application page told proceed star till useless repayment quick advice public borrow bother meet register project popped
# 3	5	loan phone fast issue update review screen amount show response ease smooth day code limit setup earn approval clean load
# 4	5	sign download rating problem reason attempt store week navigate simple touch play hope information respond seamless theme ocbc product force
# 5	5	pocket wait experience digital love deposit function space create write joke feature criterion singtel told question proper competitor start standard
# 6	5	banking apps grab error month card dont hope debit registration info link register today effort past explain cool le cash
# 7	5	transfer payee number feature interface service everytime stuck password join term feel credit bank force promise option repeat blank lousy
# 8	5	time money singpass email waste multiple access change list transaction customer goal opening receive company slot sept imagine carry gxbank
# 9	5	bank account work trust launch simple process kind singapore input doubt maximum invitation foreigner fingerprint provide compare excuse product objective
#
# <1000> LL/token: -7.36265
#
# Total time: 36 seconds
# Coherence Score:  0.6171789850040147

# %% [markdown]
# ### Visualizing LDA model topics

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamallet,doc_term_matrix,dictionary)
vis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j4/vmy9xw4d56g55p6xvtlzfb700000gn/T/ipykernel_2360/1193004992.py in <module>
#       1 pyLDAvis.enable_notebook()
# ----> 2 vis = pyLDAvis.gensim.prepare(ldamallet,doc_term_matrix,dictionary)
#       3 vis
#
# AttributeError: module 'pyLDAvis' has no attribute 'gensim'

# %%
ldamallet.print_topics()
# Out:
# [(0,
#   '0.315*"interest" + 0.237*"rate" + 0.039*"increase" + 0.030*"point" + 0.017*"consumer" + 0.017*"lack" + 0.017*"thing" + 0.017*"drop" + 0.013*"device" + 0.013*"bait"'),
#  (1,
#   '0.123*"user" + 0.052*"offer" + 0.043*"detail" + 0.038*"super" + 0.038*"design" + 0.028*"security" + 0.028*"support" + 0.028*"year" + 0.028*"payment" + 0.024*"click"'),
#  (2,
#   '0.234*"account" + 0.083*"login" + 0.063*"fund" + 0.052*"application" + 0.028*"told" + 0.024*"page" + 0.020*"star" + 0.020*"proceed" + 0.020*"repayment" + 0.016*"register"'),
#  (3,
#   '0.103*"loan" + 0.099*"phone" + 0.075*"fast" + 0.071*"issue" + 0.056*"update" + 0.056*"review" + 0.040*"screen" + 0.032*"amount" + 0.024*"show" + 0.024*"response"'),
#  (4,
#   '0.201*"sign" + 0.057*"download" + 0.038*"rating" + 0.038*"problem" + 0.033*"reason" + 0.029*"simple" + 0.029*"store" + 0.029*"attempt" + 0.024*"navigate" + 0.024*"hope"'),
#  (5,
#   '0.161*"pocket" + 0.085*"wait" + 0.081*"experience" + 0.058*"digital" + 0.049*"love" + 0.036*"deposit" + 0.031*"function" + 0.022*"create" + 0.022*"space" + 0.022*"write"'),
#  (6,
#   '0.083*"banking" + 0.078*"apps" + 0.074*"grab" + 0.074*"error" + 0.064*"month" + 0.039*"card" + 0.029*"singpass" + 0.025*"debit" + 0.025*"dont" + 0.020*"link"'),
#  (7,
#   '0.111*"transfer" + 0.078*"feature" + 0.078*"payee" + 0.069*"number" + 0.041*"interface" + 0.028*"everytime" + 0.023*"password" + 0.023*"force" + 0.018*"feel" + 0.018*"credit"'),
#  (8,
#   '0.149*"time" + 0.117*"money" + 0.073*"singpass" + 0.048*"email" + 0.032*"waste" + 0.032*"multiple" + 0.032*"change" + 0.032*"access" + 0.032*"transaction" + 0.028*"list"'),
#  (9,
#   '0.324*"bank" + 0.078*"account" + 0.074*"work" + 0.053*"trust" + 0.049*"launch" + 0.029*"simple" + 0.025*"process" + 0.020*"kind" + 0.016*"singapore" + 0.012*"input"')]

# %% [markdown]
# ### Creating a lookup table for topics

# %%
topic_lookup_data = pd.DataFrame((ldamallet.print_topics()),columns=['Topic_Number','Top_Keywords'])


topic_lookup_data['Topic_Name'] = ['App Responsiveness','Money Growth (Interest Rates)','Customer Services','Services & Products','User Interface','Credit card', 'Login & Account Setup', 'Competition', 'Safety', 'Customer trust']


topic_lookup_data = topic_lookup_data[['Topic_Number','Topic_Name','Top_Keywords']]


topic_lookup_data['Top_Keywords'] = topic_lookup_data.Top_Keywords.str\
.replace(r'[^a-z]',' ',regex=True).apply(lambda x: x.split())


topic_lookup_data.style.set_properties(subset=['Top_Keywords'], **{'width': '300px'})
# Out:
# <style type="text/css">
# #T_afe59_row0_col2, #T_afe59_row1_col2, #T_afe59_row2_col2, #T_afe59_row3_col2, #T_afe59_row4_col2, #T_afe59_row5_col2, #T_afe59_row6_col2, #T_afe59_row7_col2, #T_afe59_row8_col2, #T_afe59_row9_col2 {
#   width: 300px;
# }
# </style>
# <table id="T_afe59_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Topic_Number</th>
#       <th class="col_heading level0 col1" >Topic_Name</th>
#       <th class="col_heading level0 col2" >Top_Keywords</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afe59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afe59_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_afe59_row0_col1" class="data row0 col1" >App Responsiveness</td>
#       <td id="T_afe59_row0_col2" class="data row0 col2" >['interest', 'rate', 'increase', 'point', 'consumer', 'lack', 'thing', 'drop', 'device', 'bait']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afe59_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_afe59_row1_col1" class="data row1 col1" >Money Growth (Interest Rates)</td>
#       <td id="T_afe59_row1_col2" class="data row1 col2" >['user', 'offer', 'detail', 'super', 'design', 'security', 'support', 'year', 'payment', 'click']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afe59_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_afe59_row2_col1" class="data row2 col1" >Customer Services</td>
#       <td id="T_afe59_row2_col2" class="data row2 col2" >['account', 'login', 'fund', 'application', 'told', 'page', 'star', 'proceed', 'repayment', 'register']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afe59_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_afe59_row3_col1" class="data row3 col1" >Services & Products</td>
#       <td id="T_afe59_row3_col2" class="data row3 col2" >['loan', 'phone', 'fast', 'issue', 'update', 'review', 'screen', 'amount', 'show', 'response']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afe59_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_afe59_row4_col1" class="data row4 col1" >User Interface</td>
#       <td id="T_afe59_row4_col2" class="data row4 col2" >['sign', 'download', 'rating', 'problem', 'reason', 'simple', 'store', 'attempt', 'navigate', 'hope']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afe59_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_afe59_row5_col1" class="data row5 col1" >Credit card</td>
#       <td id="T_afe59_row5_col2" class="data row5 col2" >['pocket', 'wait', 'experience', 'digital', 'love', 'deposit', 'function', 'create', 'space', 'write']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afe59_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_afe59_row6_col1" class="data row6 col1" >Login & Account Setup</td>
#       <td id="T_afe59_row6_col2" class="data row6 col2" >['banking', 'apps', 'grab', 'error', 'month', 'card', 'singpass', 'debit', 'dont', 'link']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afe59_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_afe59_row7_col1" class="data row7 col1" >Competition</td>
#       <td id="T_afe59_row7_col2" class="data row7 col2" >['transfer', 'feature', 'payee', 'number', 'interface', 'everytime', 'password', 'force', 'feel', 'credit']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afe59_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_afe59_row8_col1" class="data row8 col1" >Safety</td>
#       <td id="T_afe59_row8_col2" class="data row8 col2" >['time', 'money', 'singpass', 'email', 'waste', 'multiple', 'change', 'access', 'transaction', 'list']</td>
#     </tr>
#     <tr>
#       <th id="T_afe59_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afe59_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_afe59_row9_col1" class="data row9 col1" >Customer trust</td>
#       <td id="T_afe59_row9_col2" class="data row9 col2" >['bank', 'account', 'work', 'trust', 'launch', 'simple', 'process', 'kind', 'singapore', 'input']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Creating new columns and inserting topic numbers and names

# %%
for index,sent in enumerate(ldamallet[doc_term_matrix]):
  topic_num =[]
  topic_details = sorted(sent,key=lambda x: x[1], reverse=True)[:2] # Getting top 2 topics in descending order
  topic_num.append(topic_details[0][0]) # Appending top topic
  if len(topic_details) > 1:
    if topic_details[1][1] > 0.35: # Appending second topic only if it has more than 35% influence on current row
      topic_num.append(topic_details[1][0])
  review_data.loc[index,'Topic_Number'] = ','.join(str(x) for x in sorted(topic_num))

  
review_data.head()
# Out:
#                                               review  \
# 0  Great banking app with attractive interest rat...
# 1  A bank like no other, no bank have such amazin...
# 2  Notice that the drop in interest rate of 0.8% ...
# 3  Sending money into my GXS account is a breeze ...
# 4  I have to say that the UI/UX is one of the bes...
#
#                                         clean_review Topic_Number
# 0  [banking, interest, rate, please, payee, numbe...            7
# 1  [bank, bank, feature, money, pocket, track, go...            9
# 2  [notice, drop, interest, rate, account, reason...            0
# 3  [money, account, breeze, amount, fund, money, ...            8
# 4  [digibank, mobile, market, player, focus, cust...            5

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamallet, corpus=doc_term_matrix, texts=review_data['clean_review'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             7.0              0.1352
# 1            1             9.0              0.1308
# 2            2             0.0              0.3367
# 3            3             8.0              0.1787
# 4            4             5.0              0.1231
# 5            5             9.0              0.2418
# 6            6             9.0              0.1443
# 7            7             3.0              0.1573
# 8            8             5.0              0.1267
# 9            9             9.0              0.2145
#
#                                             Keywords  \
# 0  transfer, feature, payee, number, interface, e...
# 1  bank, account, work, trust, launch, simple, pr...
# 2  interest, rate, increase, point, consumer, lac...
# 3  time, money, singpass, email, waste, multiple,...
# 4  pocket, wait, experience, digital, love, depos...
# 5  bank, account, work, trust, launch, simple, pr...
# 6  bank, account, work, trust, launch, simple, pr...
# 7  loan, phone, fast, issue, update, review, scre...
# 8  pocket, wait, experience, digital, love, depos...
# 9  bank, account, work, trust, launch, simple, pr...
#
#                                                 Text
# 0  [banking, interest, rate, please, payee, numbe...
# 1  [bank, bank, feature, money, pocket, track, go...
# 2  [notice, drop, interest, rate, account, reason...
# 3  [money, account, breeze, amount, fund, money, ...
# 4  [digibank, mobile, market, player, focus, cust...
# 5  [slot, account, month, nothing, whenever, anyo...
# 6  [awesome, design, theme, banking, institution,...
# 7  [fast, reversal, money, bank, time, life, fast...
# 8  [user, design, navigate, pocket, feature, wait...
# 9  [joke, nothing, input, phone, number, nothing,...

# %%
for index,topic_num in enumerate(review_data.Topic_Number):
  topic_name_list=[]
  for single_topic_num in topic_num.split(','):
    single_topic_num=int(single_topic_num)
    topic_name_list.append(topic_lookup_data.loc\
                           [topic_lookup_data.Topic_Number == single_topic_num,'Topic_Name'][single_topic_num]) 
  # Extracting topic names from lookup table
  review_data.loc[index,'Topic_Name'] =' & '.join(topic_name_list)

# %%
review_data
# Out:
#                                                 review  \
# 0    Great banking app with attractive interest rat...
# 1    A bank like no other, no bank have such amazin...
# 2    Notice that the drop in interest rate of 0.8% ...
# 3    Sending money into my GXS account is a breeze ...
# 4    I have to say that the UI/UX is one of the bes...
# ..                                                 ...
# 312  digital bank app does not work when it already...
# 313  Not ready to roll out completely. Aint even al...
# 314  Can not download yet, just always show pending...
# 315  Looks cool and sleek! Can I get an invite if I...
# 316  It's doesn't work, they're just trying to coll...
#
#                                           clean_review Topic_Number  \
# 0    [banking, interest, rate, please, payee, numbe...            7
# 1    [bank, bank, feature, money, pocket, track, go...            9
# 2    [notice, drop, interest, rate, account, reason...            0
# 3    [money, account, breeze, amount, fund, money, ...            8
# 4    [digibank, mobile, market, player, focus, cust...            5
# ..                                                 ...          ...
# 312                              [digital, bank, work]            9
# 313          [roll, aint, create, account, invitation]            9
# 314                                   [download, show]            3
# 315          [look, cool, sleek, invite, star, review]            2
# 316  [work, collect, phone, number, download, play,...            4
#
#               Topic_Name
# 0            Competition
# 1         Customer trust
# 2     App Responsiveness
# 3                 Safety
# 4            Credit card
# ..                   ...
# 312       Customer trust
# 313       Customer trust
# 314  Services & Products
# 315    Customer Services
# 316       User Interface
#
# [317 rows x 4 columns]

# %%
review_data.to_csv('topics_review.csv')
